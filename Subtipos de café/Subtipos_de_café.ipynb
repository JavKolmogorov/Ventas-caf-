# %% [markdown]
# #Importación de las librerías

# %%
import pandas as pd

# %% [markdown]
# #Importación del dataset

# %%
cafe_df = pd.read_csv('index.csv')
cafe_df.head()
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %% [markdown]
# #Desgloce de tipos de café y subtipos(en función de la variabilidad de costos)

# %%
cafe_df.groupby(["coffee_name", "money"])["money"].count()
# Out:
# coffee_name          money
# Americano            27.92     66
#                      28.90     53
#                      29.00      8
#                      30.00      6
# Americano with Milk  32.82    137
#                      33.80     51
#                      34.00      7
#                      35.00      8
# Cappuccino           37.72    110
#                      38.70     39
#                      39.00      5
#                      40.00     10
# Cocoa                37.72     13
#                      38.70      9
#                      39.00      3
#                      40.00      1
# Cortado              27.92     40
#                      28.90     40
#                      30.00      5
# Espresso             23.02     17
#                      24.00     14
#                      25.00      4
# Hot Chocolate        37.72     28
#                      38.70     29
#                      39.00      1
#                      40.00      5
# ...

# %% [markdown]
# ##Observaciones
#
# Es fácil de ver que cada tipo de café cubre 4 subtipos en función de costos; parece ser, por la precisión que ya cubre cada tipo, que la diferencia en precios no es más que una distinción de tamaños de vasos, yendo de pequeño a grande. Desde luego no podemos hacer una descripción explícita del tamaño de cada vaso, pues eso depende de los líneamientos de la tienda, sin embargo podemos esa escala básica.
